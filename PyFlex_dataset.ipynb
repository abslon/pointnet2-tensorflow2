# %%
import tensorflow as tf
from pathlib import Path
import random
import numpy as np
import h5py
import glob
import random

# %%
# parameters
work_dir = Path('/home/abslon/Workspace/pointnet2-tf2/data')  # path to data folder ex) ~/Workspace/data
env = 'DamBreak'
data_names = ['positions', 'velocities']

# %%
data_dir = work_dir / ('data_' + env)
stat_path = data_dir / 'stat.h5'
train_dir = data_dir / 'train'
vaild_dir = data_dir / 'vaild'

# %% [markdown]
# ## consume all data files - train_data, valid_data

# %%
def read_h5(data_names, path):
    hf = h5py.File(path, 'r')
    data = []
    for i in range(len(data_names)):
        d = np.array(hf.get(data_names[i]))
        data.append(d)
    hf.close()
    return data

# %%
example_data_path = train_dir / '0' / '12.h5'
example_data = read_h5(data_names, str(example_data_path))
example_data  # list of data as np.ndarray
# Out:
# [array([[0.09320369, 0.01      , 0.02530662],
#         [0.097744  , 0.01      , 0.07167163],
#         [0.0566079 , 0.01      , 0.14564845],
#         ...,
#         [0.72503525, 1.0285343 , 0.5305556 ],
#         [0.73040456, 1.0201541 , 0.5734387 ],
#         [0.7225195 , 1.0150986 , 0.6175292 ]], dtype=float32),
#  array([[-1.476855  ,  0.        , -0.36068556],
#         [-1.0073737 ,  0.        , -0.45203176],
#         [-1.4364111 ,  0.        , -0.22117494],
#         ...,
#         [-0.13065577, -2.0351171 , -0.08110284],
#         [-0.13343096, -2.1802855 , -0.15206693],
#         [-0.21788119, -2.1926022 , -0.20386575]], dtype=float32)]

# %%
train_data = list()  #[(data, next_data), ...],  data = [pos, vel]
valid_data = list()

# %%
def sort_key(path):
    names = path.split('/')
    num_str = names[-1]
    nums = [int(s) for s in num_str.split('.') if s.isdigit()]
    return nums[0]

# %%
# get train data
rollout_list = glob.glob( str(train_dir / '*') )
rollout_list = sorted(rollout_list, key=sort_key)
rollout_list
# Out:
# ['/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/0',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/1',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/2',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/3',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/4',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/6',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/7',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/8',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/9',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/10',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/11',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/12',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/13',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/14',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/15',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/16',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/17',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/18',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/19',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/20',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/22',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/23',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/24',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/25',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/26',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/27',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/28',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/29',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/30',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/31',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/32',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/33',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/34',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/35',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/36',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/37',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/38',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/39',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/40',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/41',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/42',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/43',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/44',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/45',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/46',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/47',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/48',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/49',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/50',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/51',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/52',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/53',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/54',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/55',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/56',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/57',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/58',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/59',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/60',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/61',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/62',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/63',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/64',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/65',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/66',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/67',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/68',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/69',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/70',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/71',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/72',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/73',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/74',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/75',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/76',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/77',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/78',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/79',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/80',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/81',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/82',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/83',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/84',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/85',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/86',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/87',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/88',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/89',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/90',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/91',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/92',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/93',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/94',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/95',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/96',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/97',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/98',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/99',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/100',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/101',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/102',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/103',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/104',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/105',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/106',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/107',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/108',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/109',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/110',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/111',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/112',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/113',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/114',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/115',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/116',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/117',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/118',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/119',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/120',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/121',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/122',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/123',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/124',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/125',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/126',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/127',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/128',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/129',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/130',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/131',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train

#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/937',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/938',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/939',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/940',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/941',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/942',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/943',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/944',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/945',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/946',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/947',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/948',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/949',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/950',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/951',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/952',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/953',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/954',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/955',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/956',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/957',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/958',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/959',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/960',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/961',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/962',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/963',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/964',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/965',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/966',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/967',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/968',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/969',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/970',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/971',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/972',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/973',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/974',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/975',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/976',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/977',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/978',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/979',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/980',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/981',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/982',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/983',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/984',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/985',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/986',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/987',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/988',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/989',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/990',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/991',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/992',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/993',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/994',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/995',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/996',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/997',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/998',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/999',
#  ...]

# %%
example_rollout = rollout_list[21]
example_data_list = glob.glob( str(Path(example_rollout) / '*.h5') )
example_data_list = sorted(example_data_list, key=sort_key)
example_data_list
# Out:
# ['/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/0.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/1.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/2.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/3.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/4.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/5.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/6.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/7.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/8.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/9.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/10.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/11.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/12.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/13.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/14.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/15.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/16.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/17.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/18.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/19.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/20.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/21.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/22.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/23.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/24.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/25.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/26.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/27.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/28.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/29.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/30.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/31.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/32.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/33.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/34.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/35.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/36.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/37.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/38.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/39.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/40.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/41.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/42.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/43.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/44.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/45.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/46.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/47.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/48.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/49.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/50.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/51.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/52.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/53.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/54.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/55.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/56.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/57.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/58.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/59.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/60.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/61.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/62.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/63.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/64.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/65.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/66.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/67.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/68.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/69.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/70.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/71.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/72.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/73.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/74.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/75.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/76.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/77.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/78.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/79.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/80.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/81.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/82.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/83.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/84.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/85.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/86.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/87.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/88.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/89.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/90.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/91.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/92.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/93.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/94.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/95.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/96.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/97.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/98.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/99.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/100.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/101.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/102.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/103.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/104.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/105.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/106.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/107.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/108.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/109.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/110.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/111.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/112.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/113.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/114.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/115.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/116.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/117.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/118.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/119.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/120.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/121.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/122.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/123.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/124.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/125.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/126.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/127.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/128.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/129.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/130.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/131.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/132.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/133.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/134.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/135.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/136.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/137.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/138.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/139.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/140.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/141.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/142.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/143.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/144.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/145.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/146.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/147.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/148.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/149.h5',
#  '/home/abslon/Workspace/pointnet2-tf2/data/data_DamBreak/train/21/150.h5']

# %%
#suffle rollout list
random.shuffle(rollout_list)
for ro in rollout_list:
    data_path_list = glob.glob( str(Path(ro) / '*.h5') )
    data_path_list = sorted(data_path_list, key=sort_key)
    
    random.shuffle(data_path_list)
    for idx in range(len(data_path_list)):
        # if idx is the last index of the list, continue
        if idx == len(data_path_list) - 1:
            continue
            
        data = read_h5(data_names, data_path_list[idx])
        data_nxt = read_h5(data_names, data_path_list[idx+1])
        
        train_data.append((data, data_nxt))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d7bd9b4369e1> in <module>
#      11             continue
#      12
# ---> 13         data = read_h5(data_names, data_path_list[idx])
#      14         data_nxt = read_h5(data_names, data_path_list[idx+1])
#      15
#
# <ipython-input-4-b66ebd34dff3> in read_h5(data_names, path)
#       3     data = []
#       4     for i in range(len(data_names)):
# ----> 5         d = np.array(hf.get(data_names[i]))
#       6         data.append(d)
#       7     hf.close()
#
# KeyboardInterrupt:
